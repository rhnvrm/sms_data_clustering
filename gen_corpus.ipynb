# %%
import numpy as np
import pandas as pd
import nltk
import re
from collections import Counter
import string
import math

# %%
corpus = pd.read_csv("sms.csv")
corpus["message"] = corpus["message"].str.lower()

# %%
# src: http://ir.dcs.gla.ac.uk/resources/linguistic_utils/stop_words
def removeStopwords(sentence):
    
    sentence= re.sub('[^A-Za-z0-9]+', ' ', sentence)

    stopwords = ['a', 'about', 'above', 'across', 'after', 'afterwards']
    stopwords += ['again', 'against', 'all', 'almost', 'alone', 'along']
    stopwords += ['already', 'also', 'although', 'always', 'am', 'among']
    stopwords += ['amongst', 'amoungst', 'amount', 'an', 'and', 'another']
    stopwords += ['any', 'anyhow', 'anyone', 'anything', 'anyway', 'anywhere']
    stopwords += ['are', 'around', 'as', 'at', 'back', 'be', 'became']
    stopwords += ['because', 'become', 'becomes', 'becoming', 'been']
    stopwords += ['before', 'beforehand', 'behind', 'being', 'below']
    stopwords += ['beside', 'besides', 'between', 'beyond', 'bill', 'both']
    stopwords += ['bottom', 'but', 'by', 'call', 'can', 'cannot', 'cant']
    stopwords += ['co', 'computer', 'con', 'could', 'couldnt', 'cry', 'de']
    stopwords += ['describe', 'detail', 'did', 'do', 'done', 'down', 'due']
    stopwords += ['during', 'each', 'eg', 'eight', 'either', 'eleven', 'else']
    stopwords += ['elsewhere', 'empty', 'enough', 'etc', 'even', 'ever']
    stopwords += ['every', 'everyone', 'everything', 'everywhere', 'except']
    stopwords += ['few', 'fifteen', 'fifty', 'fill', 'find', 'fire', 'first']
    stopwords += ['five', 'for', 'former', 'formerly', 'forty', 'found']
    stopwords += ['four', 'from', 'front', 'full', 'further', 'get', 'give']
    stopwords += ['go', 'had', 'has', 'hasnt', 'have', 'he', 'hence', 'her']
    stopwords += ['here', 'hereafter', 'hereby', 'herein', 'hereupon', 'hers']
    stopwords += ['herself', 'him', 'himself', 'his', 'how', 'however']
    stopwords += ['hundred', 'i', 'ie', 'if', 'in', 'inc', 'indeed']
    stopwords += ['interest', 'into', 'is', 'it', 'its', 'itself', 'keep']
    stopwords += ['last', 'latter', 'latterly', 'least', 'less', 'ltd', 'made']
    stopwords += ['many', 'may', 'me', 'meanwhile', 'might', 'mill', 'mine']
    stopwords += ['more', 'moreover', 'most', 'mostly', 'move', 'much']
    stopwords += ['must', 'my', 'myself', 'name', 'namely', 'neither', 'never']
    stopwords += ['nevertheless', 'next', 'nine', 'no', 'nobody', 'none']
    stopwords += ['noone', 'nor', 'not', 'nothing', 'now', 'nowhere', 'of']
    stopwords += ['off', 'often', 'on','once', 'one', 'only', 'onto', 'or']
    stopwords += ['other', 'others', 'otherwise', 'our', 'ours', 'ourselves']
    stopwords += ['out', 'over', 'own', 'part', 'per', 'perhaps', 'please']
    stopwords += ['put', 'rather', 're', 's', 'same', 'see', 'seem', 'seemed']
    stopwords += ['seeming', 'seems', 'serious', 'several', 'she', 'should']
    stopwords += ['show', 'side', 'since', 'sincere', 'six', 'sixty', 'so']
    stopwords += ['some', 'somehow', 'someone', 'something', 'sometime']
    stopwords += ['sometimes', 'somewhere', 'still', 'such', 'system', 'take']
    stopwords += ['ten', 'than', 'that', 'the', 'their', 'them', 'themselves']
    stopwords += ['then', 'thence', 'there', 'thereafter', 'thereby']
    stopwords += ['therefore', 'therein', 'thereupon', 'these', 'they']
    stopwords += ['thick', 'thin', 'third', 'this', 'those', 'though', 'three']
    stopwords += ['three', 'through', 'throughout', 'thru', 'thus', 'to']
    stopwords += ['together', 'too', 'top', 'toward', 'towards', 'twelve']
    stopwords += ['twenty', 'two', 'un', 'under', 'until', 'up', 'upon']
    stopwords += ['us', 'very', 'via', 'was', 'we', 'well', 'were', 'what']
    stopwords += ['whatever', 'when', 'whence', 'whenever', 'where']
    stopwords += ['whereafter', 'whereas', 'whereby', 'wherein', 'whereupon']
    stopwords += ['wherever', 'whether', 'which', 'while', 'whither', 'who']
    stopwords += ['whoever', 'whole', 'whom', 'whose', 'why', 'will', 'with']
    stopwords += ['within', 'without', 'would', 'yet', 'you', 'your']
    stopwords += ['yours', 'yourself', 'yourselves']
    return ' '.join([w for w in sentence.split() if w not in stopwords])

# %%
def clean_sms(string):
    sms = []
    regexp = r'^([^0-9]*)$'
    for i in nltk.word_tokenize(removeStopwords(str(string))):
        if re.match(regexp, i):
            word = nltk.PorterStemmer().stem(i.lower())
            sms += [word]
    return ' '.join(sms)

corpus["message"] = corpus["message"].apply(clean_sms)

# %%
wordlist = Counter()
corpus["message"].str.split().apply(wordlist.update)
wordlist
# Out:
# Counter({'paiy': 5,
#          'udupi': 1,
#          'daffodil': 2,
#          'payabl': 17,
#          'bicftd': 1,
#          'song': 15,
#          'saha': 1,
#          'bankloan': 1,
#          'ramayana': 1,
#          'digibank': 6,
#          'lokeshreddi': 1,
#          'sreedhara': 1,
#          'neelsandra': 4,
#          'ur': 112,
#          'cctv': 2,
#          'membership': 32,
#          'codenamemega': 1,
#          'autotech': 1,
#          'bhavishya': 2,
#          'anshul': 1,
#          'rang': 39,
#          'sajjad': 1,
#          'vani': 1,
#          'gujjubhai': 3,
#          'jayaprakash': 5,
#          'mdfaiz': 1,
#          'lookwel': 2,
#          'rohan': 3,
#          'shrikant': 1,
#          'santro': 860,
#          'jackpot': 4,
#          'krishnamurthi': 1,
#          'sei': 3,
#          'pooja': 3,
#          'chandra': 2,
#          'rupesh': 1,
#          'huge': 4,
#          'victor': 3,
#          'xj': 2,
#          'upload': 32,
#          'flash': 13,
#          'sabudana': 91,
#          'ranganath': 1,
#          'cartrad': 27,
#          'karnataka': 40,
#          'rsvp': 1,
#          'pranav': 1,
#          'lakshmeesh': 2,
#          'bhuvanesh': 1,
#          'devjyoti': 1,
#          'quit': 2,
#          'xpress': 2,
#          'ggindia': 2,
#          'pancard': 1,
#          'ghori': 1,
#          'tool': 4,
#          'digvijay': 1,
#          'indiranagar': 91,
#          'arshad': 7,
#          'acharya': 3,
#          'mmifleet': 1,
#          'pushpa': 1,
#          'system': 6,
#          'yoga': 1,
#          'meenasre': 1,
#          'nearbi': 4,
#          'gallari': 4,
#          'parveen': 1,
#          'evalu': 2,
#          'sukanta': 1,
#          'introduc': 8,
#          'buyback': 4,
#          'sghdfc': 1,
#          'npskrm': 187,
#          'jiomus': 2,
#          'jv': 1,
#          'sandeep': 19,
#          'dhankad': 1,
#          'fomat': 1,
#          'logist': 3,
#          'haleem': 1,
#          'ucinc': 2,
#          'dine': 13,
#          'burgerpizza': 4,
#          'kaverappa': 1,
#          'boo': 1,
#          'ship': 17,
#          'visit': 236,
#          'arvind': 8,
#          'bmicapa': 1,
#          'rigor': 1,
#          'cv': 28,
#          'jatin': 1,
#          'rathod': 1,
#          'bike': 3,
#          'senior': 2,
#          'convey': 1,
#          'cdi': 7,
#          'nagraj': 4,
#          'minut': 46,
#          'type': 8,
#          'expo': 3,
#          'upgrad': 32,
#          'garb': 1,
#          'aruna': 1,
#          'flag': 4,
#          'defenc': 1,
#          'export': 1,
#          'right': 9,
#          'benji': 1,
#          'makeup': 4,
#          'soumik': 1,
#          'bookingid': 13,
#          'veggi': 5,
#          'cooper': 13,
#          'refriger': 2,
#          'falken': 2,
#          'asgar': 1,
#          'joseph': 5,
#          'jc': 1,
#          'zire': 1,
#          'experienc': 5,
#          'candl': 2,
#          'ane': 1,
#          'god': 2,
#          'kanti': 1,
#          'mobilereceipt': 6,
#          'grnd': 3,
#          'mane': 1,
#          'sumit': 10,
#          'pramodh': 1,
#          'vichar': 9,
#          'tmrw': 3,
#          'dhamaka': 3,
#          'vfapp': 2,
#          'spicejet': 1,
#          'punit': 1,
#          'morn': 5,
#          'extend': 15,
#          'coconut': 1,
#          'ismail': 2,
#          'gowardhan': 1,
#          'abdul': 6,
#          'look': 20,
#          'tsi': 2,
#          'galaxi': 11,
#          'kotakcard': 1,
#          'lopa': 1,
#          'devendra': 3,
#          'shiva': 10,
#          'sea': 3,
#          'awesom': 6,
#          'rc': 23,
#          'canada': 2,
#          'yashasvi': 1,
#          'coin': 3,
#          'quot': 8,
#          'origin': 4,
#          'method': 7,
#          'rajamani': 1,
#          'akarsh': 1,
#          'parmeshwar': 1,
#          'pizzahut': 1,
#          'stall': 4,
#          'crde': 4,
#          'accept': 68,
#          'entri': 13,
#          'siddartha': 1,
#          'propos': 3,
#          'son': 1,
#          'bhavi': 1,
#          'dth': 5,
#          'asifkhan': 1,
#          'lakshachandi': 6,
#          'feraz': 1,
#          'multipurpos': 4,
#          'faisal': 1,
#          'urin': 4,
#          'dlx': 2,
#          'potdar': 1,
#          'believ': 7,
#          'kri': 2,
#          'sbt': 1,
#          'abhishekgouda': 1,
#          'parent': 160,
#          'highest': 45,
#          'kidney': 1,
#          'despit': 1,
#          'inern': 2,
#          'shane': 1,
#          'chiranjeevi': 1,
#          'sreejith': 2,
#          'mettal': 2,
#          'natur': 3,
#          'mdiabet': 1,
#          'onelink': 12,
#          'indiamart': 4,
#          'neerja': 1,
#          'cte': 18,
#          'gopal': 1,
#          'bhavan': 1,
#          'owner': 1631,
#          'perk': 4,
#          'play': 8,
#          'rishabh': 1,
#          'solur': 1,
#          'homeassist': 2,
#          'android': 20,
#          'kishen': 1,
#          'priyanta': 1,
#          'mesco': 1,
#          'enp': 3,
#          'thank': 400,
#          'partnersupport': 6,
#          'shanthi': 4,
#          'fold': 1,
#          'blue': 61,
#          'chakan': 1,
#          'triennial': 1,
#          'uberpool': 5,
#          'iytc': 1,
#          'rajasthan': 4,
#          'bilal': 1,
#          'amarendra': 1,
#          'bareilli': 1,
#          'krishnagiri': 1,
#          'takeaway': 1,
#          'tegd': 1,
#          'reschedul': 2,
#          'taxi': 11,
#          'carpet': 4,
#          'magma': 3,
#          'neavin': 1,
#          'detail': 1500,
#          'callertun': 5,
#          'whe': 2,
#          'ramareddi': 3,
#          'som': 1,
#          'trade': 12,
#          'cpc': 2,
#          'breathabl': 1,
#          'rohith': 2,
#          'site': 30,
#          'potato': 1,
#          'magicbrick': 14,
#          'constrain': 1,
#          'kandoi': 4,
#          'withdrawn': 5,
#          'atif': 1,
#          'innova': 46,
#          'hari': 5,
#          'tabrez': 1,
#          'mihir': 6,
#          'websit': 62,
#          'sonal': 1,
#          'gel': 6,
#          'flora': 1,
#          'thyagraj': 4,
#          'home': 163,
#          'chiru': 2,
#          'stone': 1,
#          'jayakumar': 1,
#          'kya': 12,
#          'abhijeet': 1,
#          'train': 3,
#          'junction': 1,
#          'begun': 1,
#          'submit': 29,
#          'sirf': 7,
#          'updat': 113,
#          'chanc': 22,
#          'ghia': 1,
#          'jeep': 9,
#          'monday': 41,
#          'nat': 17,
#          'sadli': 1,
#          'iplua': 1,
#          'waveboard': 1,
#          'gurgaon': 7,
#          'kaushik': 2,
#          'anjaan': 2,
#          'amg': 1,
#          'ganga': 1,
#          'deliveri': 1022,
#          'excit': 52,
#          'kemp': 2,
#          'job': 5,
#          'apprvd': 1,
#          'ah': 1,
#          'zenestiloka': 1,
#          'facial': 9,
#          'cg': 9,
#          'say': 18,
#          'kennedi': 2,
#          'mba': 1,
#          'ramachandran': 1,
#          'freshmenu': 1,
#          'keerthi': 2,
#          'namskar': 1,
#          'wmachin': 2,
#          'fort': 2,
#          'siddiq': 1,
#          'abba': 2,
#          'good': 29,
#          'signatur': 12,
#          'receipt': 36,
#          'kccbk': 4,
#          'maurya': 1,
#          'chapter': 1,
#          'senthilkumar': 1,
#          'agraw': 3,
#          'octacor': 1,
#          'senapati': 1,
#          'growth': 63,
#          'satisfactori': 4,
#          'mnth': 3,
#          'selva': 1,
#          'mrp': 9,
#          'mock': 2,
#          'arya': 1,
#          'rajesh': 21,
#          'bellari': 1,
#          'rais': 7,
#          'tranx': 14,
#          'mantri': 1,
#          'snpdl': 20,
#          'ii': 11,
#          'narendra': 14,
#          'gib': 6,
#          'ucsam': 1,
#          'shekar': 5,
#          'suzuki': 4623,
#          'dolar': 1,
#          'utsav': 5,
#          'benefit': 21,
#          'dwara': 1,
#          'reddi': 32,
#          'vairavel': 1,
#          'sfx': 1,
#          'jaynagar': 2,
#          'inam': 1,
#          'eshwaran': 1,
#          'raheja': 1,
#          'children': 10,
#          'wh': 1,
#          'compani': 34,
#          'jaishankar': 2,
#          'jha': 1,
#          'mangaraj': 1,
#          'avinash': 2,
#          'nellor': 1,
#          'adarsh': 2,
#          'crn': 20,
#          'col': 3,
#          'bene': 1,
#          'mover': 1,
#          'concept': 2,
#          'construct': 3,
#          'congratul': 12,
#          'career': 2,
#          'kapil': 1,
#          'current': 227,
#          'empir': 1,
#          'pod': 1,
#          'camri': 2,
#          'dasara': 4,
#          'second': 6,
#          'amith': 2,
#          'ponnap': 1,
#          'soon': 27,
#          'rajbeer': 1,
#          'piyush': 5,
#          'rental': 4,
#          'appli': 169,
#          'riaz': 1,
#          'asset': 2,
#          'vikram': 5,
#          'ministri': 4,
#          'household': 8,
#          'toothsom': 1,
#          'brown': 8,
#          'heat': 2,
#          'yippe': 1,
#          'pimpl': 2,
#          'formal': 4,
#          'kora': 1,
#          'bate': 1,
#          'pruthvi': 1,
#          'mohd': 2,
#          'brahm': 1,
#          'occur': 1,
#          'surveil': 1,
#          'shrusti': 2,
#          'togeth': 2,
#          'nicb': 8,
#          'ffsampl': 1,
#          'bata': 7,
#          'manthansanghvi': 1,
#          'gd': 49,
#          'freedom': 9,
#          'puls': 6,
#          'sahid': 1,
#          'resend': 1,
#          'harish': 8,
#          'birj': 1,
#          'kit': 12,
#          'numer': 1,
#          'jaswant': 1,
#          'sheshadri': 1,
#          'genuin': 1,
#          'sherya': 1,
#          'leas': 5,
#          'uplabdh': 2,
#          'bhandari': 1,
#          'tr': 117,
#          'gb': 5,
#          'ggn': 1,
#          'lot': 12,
#          'black': 58,
#          'bang': 55,
#          'kazin': 1,
#          'radha': 2,
#          'nag': 2,
#          'unbeliev': 1,
#          'bhk': 31,
#          'red': 67,
#          'menon': 2,
#          'bing': 2,
#          'credenti': 1,
#          'extens': 3,
#          'dnd': 6,
#          'hyderabad': 2,
#          'ayilliath': 1,
#          'vitara': 3,
#          'aadhaar': 35,
#          'murthi': 9,
#          'sens': 1,
#          'vjb': 2,
#          'programm': 13,
#          'sharad': 2,
#          'room': 7,
#          'ph': 64,
#          'arnag': 1,
#          'finmin': 1,
#          'vithal': 1,
#          'paresh': 1,
#          'msid': 2,
#          'aaditya': 1,
#          'lavish': 2,
#          'equip': 1,
#          'fear': 3,
#          'firm': 2,
#          'amritsar': 3,
#          'htm': 11,
#          'activ': 102,
#          'bellandur': 1589,
#          'kokilaben': 1,
#          'wallet': 43,
#          'loanzentechnologiesp': 2,
#          'ev': 1,
#          'neeraj': 4,
#          'pinki': 3,
#          'liy': 6,
#          'enemi': 1,
#          'vishwasrao': 1,
#          'dj': 2,
#          'customerservic': 2,
#          'ab': 54,
#          'pillai': 4,
#          'iso': 1,
#          'genni': 1,
#          'ajesh': 1,
#          'dutta': 5,
#          'rmn': 1,
#          'exam': 9,
#          'hitesh': 1,
#          'inv': 10,
#          'satement': 1,
#          'wl': 4,
#          'shuru': 1,
#          'noon': 23,
#          'haiku': 2,
#          'denomin': 1,
#          'pali': 1,
#          'desai': 2,
#          'upd': 3,
#          'fruit': 10,
#          'hitech': 1,
#          'sarvottam': 1,
#          'versa': 1,
#          'audio': 5,
#          'pymt': 17,
#          'maximum': 6,
#          'waiv': 3,
#          'seshadrik': 1,
#          'jio': 46,
#          'u': 56,
#          'flu': 4,
#          'maharaja': 197,
#          'chiranth': 4,
#          'tisb': 4,
#          'famili': 73,
#          'vemulap': 4,
#          'nevn': 2,
#          'sundeep': 1,
#          'comfort': 3,
#          'prabhu': 8,
#          'real': 7,
#          'classteach': 2,
#          'bhupendra': 1,
#          'megastor': 6,
#          'opt': 94,
#          'trxn': 58,
#          'silvver': 1,
#          'bramarambha': 2,
#          'navin': 2,
#          'increas': 3,
#          'regular': 22,
#          'ola': 97,
#          'chose': 1,
#          'swain': 1,
#          'bimal': 1,
#          'technic': 11,
#          'pinnacl': 1,
#          'prabhakar': 3,
#          'agsar': 1,
#          'mr': 32,
#          'do': 2,
#          'mpin': 14,
#          'paisa': 2,
#          'amid': 1,
#          'ad': 150,
#          'ajaykiran': 1,
#          'tax': 82,
#          'feder': 2,
#          'thejdeep': 2,
#          'uninterrupt': 60,
#          'purpos': 1,
#          'record': 7,
#          'commit': 4,
#          'tourism': 1,
#          'featur': 12,
#          'sajan': 2,
#          'spectra': 1,
#          'consent': 3,
#          'tjsbbank': 1,
#          'anjani': 35,
#          'upcom': 1,
#          'nandheesh': 1,
#          'colombo': 2,
#          'dec': 238,
#          'combo': 16,
#          'pancham': 2,
#          'octoberluck': 1,
#          'finanac': 1,
#          'cerejo': 1,
#          'dcbapp': 4,
#          'bvc': 1,
#          'vimalkanth': 1,
#          'ucb': 6,
#          'natarajan': 2,
#          'strng': 7,
#          'itlcxatw': 1,
#          'shall': 8,
#          'salma': 1,
#          'plu': 20,
#          'lene': 1,
#          'pf': 1,
#          'll': 6,
#          'rblfunbegin': 1,
#          'jagmohan': 1,
#          'weather': 3,
#          'debit': 1201,
#          'mn': 9,
#          'psft': 1,
#          'geater': 1,
#          'brijbhushan': 1,
#          'googl': 7,
#          'kartthik': 1,
#          'keen': 1,
#          'tyre': 22,
#          'dongad': 1,
#          'q': 113,
#          'wholesal': 41,
#          'dash': 5,
#          'enter': 91,
#          'kr': 12,
#          'north': 5,
#          'jiotv': 2,
#          'shezan': 2,
#          'rblreward': 2,
#          'r': 702,
#          'downtim': 1,
#          'dow': 1,
#          'rath': 6,
#          'jsp': 7,
#          'prayer': 1,
#          'viveknagar': 4,
#          'distanc': 2,
#          'mfcwl': 430,
#          'trivandrum': 5,
#          'chakkar': 1,
#          'happend': 1,
#          'sanjeeth': 1,
#          'parthiban': 2,
#          'raksha': 1,
#          'narayanrao': 1,
#          'lakshmireddi': 2,
#          'sudhar': 2,
#          'z': 2,
#          'access': 106,
#          'tuhina': 1,
#          'amaz': 142,
#          'prajith': 2,
#          'automat': 6,
#          'vakul': 1,
#          'extravaganza': 2,
#          'hai': 28,
#          'req': 4,
#          'web': 5,
#          'chandrasekhar': 3,
#          'kindli': 244,
#          'exl': 1,
#          'taind': 1,
#          'joy': 15,
#          'rech': 3,
#          'mahagun': 1,
#          'nirmali': 1,
#          'diamond': 8,
#          'work': 61,
#          'part': 13,
#          'monarch': 1,
#          'qualiti': 6,
#          'smartbyt': 6,
#          'hinduja': 5,
#          'krishanth': 1,
#          'district': 5,
#          'baig': 1,
#          'creditcard': 10,
#          'delta': 4,
#          'eta': 1,
#          'goa': 2,
#          'insruct': 2,
#          'ramu': 3,
#          'shenoikar': 1,
#          'wd': 4,
#          'kaushal': 1,
#          'qualifi': 7,
#          'murtuza': 1,
#          'kotak': 131,
#          'kushal': 2,
#          'ameenuddin': 1,
#          'obdii': 4,
#          'court': 4,
#          'vgsbabu': 1,
#          'whop': 1,
#          'kushalappa': 1,
#          'aman': 6,
#          'circul': 2,
#          'tue': 5,
#          'inclus': 9,
#          'shakir': 1,
#          'raguraman': 1,
#          'rupeek': 1,
#          'itkgrcvv': 3,
#          'publish': 58,
#          'bibin': 2,
#          'bhavesh': 4,
#          'upi': 5,
#          'maintain': 9,
#          'punjab': 6,
#          'love': 33,
#          'superior': 44,
#          'audi': 19,
#          'compulsori': 10,
#          'mix': 99,
#          'mb': 17,
#          'sonu': 1,
#          'chandrashekar': 8,
#          'vp': 4,
#          'chand': 2,
#          'transf': 2,
#          'resu': 3,
#          'biiie': 2,
#          'pandiyan': 4,
#          'login': 190,
#          'immun': 2,
#          'nadeem': 7,
#          'cheesilici': 1,
#          'bonaza': 1,
#          'fortifi': 1,
#          'dinnerset': 1,
#          'respect': 6,
#          'afridi': 1,
#          'sriharsha': 1,
#          'singh': 48,
#          'indra': 1,
#          'reuben': 2,
#          'ck': 1,
#          'madhu': 14,
#          'digitaltv': 32,
#          'myairtelapp': 2,
#          'kinjal': 1,
#          'siddiquk': 1,
#          'infant': 5,
#          'ebay': 4,
#          'bazar': 1,
#          'laptop': 4,
#          'sm': 362,
#          'kharidi': 2,
#          'feliton': 3,
#          'vishnu': 1,
#          'premium': 34,
#          'vistaaa': 1,
#          'care': 84,
#          'prioriti': 2,
#          'call': 157,
#          'richhariya': 1,
#          'nayeem': 1,
#          'vodafon': 309,
#          'arijit': 1,
#          'expressway': 2,
#          'dora': 1,
#          'sam': 9,
#          'sunil': 15,
#          'enabl': 6,
#          'keep': 1,
#          'vivek': 31,
#          'ahead': 5,
#          'signific': 1,
#          'eze': 7,
#          'ott': 1,
#          'decathlon': 12,
#          'quick': 38,
#          'ganeshaya': 5,
#          'pratima': 1,
#          'saravana': 1,
#          'don': 72,
#          'pasha': 1,
#          'vivin': 1,
#          'name': 3,
#          'biggest': 7,
#          'insur': 64,
#          'quickli': 5,
#          'priyam': 4,
#          'tkt': 1,
#          'javeedfaiz': 1,
#          'shre': 1,
#          'iii': 66,
#          'plo': 9,
#          'modak': 1,
#          'winpin': 14,
#          'collect': 1037,
#          'mad': 11,
#          'merun': 2,
#          'henceforth': 1,
#          'bookmyshow': 63,
#          'cab': 44,
#          'freecharg': 21,
#          'proton': 1,
#          'fraudster': 1,
#          'diabet': 3,
#          'aa': 5,
#          'seelam': 1,
#          'indiranagarbranch': 1,
#          'url': 2,
#          'township': 1,
#          'onkvl': 1,
#          'dmart': 6,
#          'beke': 1,
#          'jinnitk': 1,
#          'slowdown': 3,
#          'midway': 2,
#          'digitatv': 1,
#          'brush': 1,
#          'rameja': 1,
#          'singl': 8,
#          'kar': 1,
#          'nano': 441,
#          'halid': 1,
#          'shroff': 1,
#          'baligar': 1,
#          'shridhar': 1,
#          'amo': 2,
#          'fundvalu': 2,
#          'dot': 2,
#          'ananthakrishna': 1,
#          'ramaswami': 1,
#          'rahil': 1,
#          'karein': 1,
#          'kaleem': 1,
#          'funfil': 2,
#          'overhaul': 2,
#          'pralhada': 1,
#          'ngr': 1,
#          'ananthkumar': 1,
#          'lieu': 1,
#          'rangaram': 1,
#          'organ': 1,
#          'drink': 8,
#          'pleas': 6,
#          'mislead': 4,
#          'reach': 408,
#          'bhundaram': 1,
#          'appmb': 3,
#          'corner': 3,
#          'conf': 1,
#          'continu': 112,
#          'interschool': 1,
#          'harsha': 4,
#          'payment': 664,
#          'estmt': 9,
#          'prosecut': 14,
#          'nationwid': 1,
#          'proc': 1,
#          'zahur': 1,
#          'ghaziabad': 1,
#          'narkhed': 2,
#          'sadhguna': 1,
#          'asxyxysvsv': 2,
#          'hyundi': 1,
#          'inox': 3,
#          'chethan': 6,
#          'enhanc': 16,
#          'kolkata': 3,
#          'joke': 1,
#          'sait': 1,
#          'english': 3,
#          'hussain': 3,
#          'myinsur': 1,
#          'jald': 1,
#          'guru': 3,
#          'clubmahindra': 80,
#          'rajarajan': 1,
#          'door': 3,
#          'jil': 1,
#          'world': 16,
#          'farm': 2,
#          'daji': 1,
#          'mxbi': 14,
#          'dawood': 2,
#          'reason': 32,
#          'kandivli': 6,
#          'poster': 1,
#          'goe': 3,
#          'errand': 1,
#          'bmsoffer': 10,
#          'kh': 1,
#          'cyber': 2,
#          'fm': 1,
#          'jbo': 3,
#          'delish': 1,
#          'stick': 1,
#          'sathyanarayana': 1,
#          'comp': 2,
#          'gxi': 18,
#          'sunderrajan': 1,
#          'litr': 3,
#          'yojna': 1,
#          'jaganmohana': 1,
#          'gsi': 4,
#          'kumaraswami': 2,
#          'issu': 45,
#          'chandan': 4,
#          'mukund': 1,
#          'fiat': 134,
#          'collag': 2,
#          'big': 6,
#          'babi': 2,
#          'gupta': 49,
#          'unib': 1,
#          'newgen': 2,
#          'aapki': 5,
#          'rangaswami': 1,
#          'xenon': 3,
#          'sharekhan': 14,
#          'prompt': 11,
#          'maharashtra': 12,
#          'caus': 16,
#          'shabbir': 1,
#          'won': 6,
#          'write': 17,
#          'respons': 19,
#          'waran': 1,
#          'oyo': 1,
#          'certain': 1,
#          'thar': 2,
#          'sanjit': 1,
#          'president': 9,
#          'jaguar': 4,
#          'ranjan': 2,
#          'slice': 279,
#          'friend': 37,
#          'zoppmo': 12,
#          'cracker': 1,
#          'kinder': 1,
#          'electron': 22,
#          'forest': 1,
#          'settlement': 1,
#          'conquer': 2,
#          'summari': 1,
#          'crcard': 1,
#          'thin': 1,
#          'vijetaon': 1,
#          'driven': 1,
#          'cargo': 2,
#          'win': 28,
#          'papaya': 1,
#          'nqrpdz': 1,
#          'chip': 6,
#          'dowload': 2,
#          'iyp': 1,
#          'gx': 10,
#          'given': 18,
#          'wnut': 2,
#          'sujith': 8,
#          'rtg': 110,
#          'swasthik': 1,
#          'wine': 4,
#          'headphon': 2,
#          'muralidhar': 1,
#          'unauthor': 2,
#          'akshay': 6,
#          'cut': 15,
#          'wed': 29,
#          'alaava': 1,
#          'iin': 60,
#          'paytm': 120,
#          'umashankar': 1,
#          'debat': 1,
#          'rocher': 1,
#          'biometr': 2,
#          'aura': 13,
#          'haldi': 1,
#          'psf': 3,
#          'congrat': 8,
#          'reduc': 8,
#          'orient': 4,
#          'gudi': 4,
#          'sb': 53,
#          'vasudeo': 1,
#          'vet': 2,
#          'purnima': 1,
#          'rxl': 10,
#          'paarth': 2,
#          'sudhir': 10,
#          'peter': 7,
#          'hsr': 4,
#          'carat': 1,
#          'forti': 5,
#          'emailid': 2,
#          'pm': 166,
#          'organis': 2,
#          'rachna': 1,
#          'dart': 6,
#          'tatacard': 1,
#          'panduranga': 1,
#          'alapati': 1,
#          'ravichandran': 1,
#          'za': 1,
#          'vacat': 8,
#          'optout': 4,
#          'renew': 67,
#          'birthdat': 1,
#          'rp': 2,
#          'shahi': 1,
#          'palava': 3,
#          'sc': 2,
#          'cinemacod': 13,
#          'jam': 4,
#          'lead': 23,
#          'std': 24,
#          'higher': 15,
#          'manag': 95,
#          'ct': 4,
#          'xrbia': 2,
#          'valley': 2,
#          'isbeyondcarz': 1,
#          'raghunandan': 3,
#          'jacob': 4,
#          'wasim': 1,
#          'august': 33,
#          'mitsubishi': 7,
#          'unpaid': 1,
#          'effici': 1,
#          'debapratim': 1,
#          'albin': 1,
#          'prior': 5,
#          'virar': 1,
#          'initi': 65,
#          'govindrajan': 1,
#          'narasimhamurthi': 1,
#          'saw': 1,
#          'diju': 1,
#          'reload': 2,
#          'finserv': 6,
#          'cmh': 10,
#          'shashidar': 1,
#          'govern': 12,
#          'didn': 1,
#          ...})

# %%
words = pd.DataFrame.from_dict(wordlist, orient='index').reset_index()
words = words.rename(columns={'index':'word', 0:'count'})
num_words = len(corpus)

# %%
words["idf"] = words.apply(lambda x: math.log10(num_words/(1 + x["count"])), axis=1)

# %%
def tf(s):
    d = dict(Counter(s))
    for k in d.keys():
        d[k] = d[k] / len(d)
    return d

corpus["tf"] = corpus.apply(lambda x: tf(x["message"].split()), axis=1)

# %%
words = words.set_index("word")

# %%
def tfidf(tf):
    tfidf = {}
    for k in tf.keys():
        tfidf[k] = tf[k] * words.loc(k)[k].idf
    return tfidf

corpus["tfidf"] = corpus.apply(lambda x: tfidf(x["tf"]), axis=1)

# %%
# Uncomment to save to CSV
# corpus.to_csv("corpus.csv")

# %%
#sim = np.zeros(shape=(len(corpus), len(corpus)))

#for i in range(len(corpus)):
#    for j in range(len(corpus)):
#        #x = corpus.loc(i)[i].tfidf
#        #y = corpus.loc(j)[j].tfidf
#        if i == j:
#            sim[i][j] = 1.0
#        if i > j:
#            sim[i][j] = sim[j][i]
#        else:
#            sim[i][j] = -1.0
#        
#sim

# %%
corpus
# Out:
#        id     sender                                            message  \
# 0      29  HP-CARFIN                                         verif code
# 1      29  RM-ICICIB  dear custom ac credit oct info mmt net avail b...
# 2      29  VK-ICICIB   dear custom c credit rs oct c link mobil imp ref
# 3      29  VK-ICICIB  ac debit atm cash wdl avbl bal bank phone imob...
# 4      29  RM-ICICIB  ac debit atm cash wdl avbl bal bank phone imob...
# 5      29  AM-TIKONA  suspens alert tikona wi bro account overdu dea...
# 6      29  AM-TIKONA  receiv cash payment rs serviceid vivek singh b...
# 7      29  VM-CARTRD  vw financ mumbai onlin auction live www cartra...
# 8      29  VM-ICICIB  dear custom debit card purchas oct info iin ww...
# 9      29  VK-ICICIB  dear custom debit card purchas oct info min bh...
# 10     29  DM-CARSTF  dear carz payment day make payment immedi avoi...
# 11     29  DM-CARSTF  dear carz payment wagon r day make payment imm...
# 12     25  HP-CARFIN                                         verif code
# 13     25  IM-AROGAY  free vitamind aarogya profil lipid liver kidne...
# 14     25  MM-MSGIND        applic car receiv receiv loan offer shortli
# 15     25  MM-MSGIND        applic car receiv receiv loan offer shortli
# 16     25  VM-ICICIB  dear custom debit card purchas oct info vp ama...
# 17     25  VK-ICICIB  ac debit atm cash wdl avbl bal bank phone imob...
# 18     25  VK-ICICIB                dear custom net avail balanc ac inr
# 19     25  MD-ICONAC  time histori ncr luckydraw disc villa conac ne...
# 20     10  HP-CARFIN                                         verif code
# 21     10  DM-HSJOYY  festiv home clean packag earli bird discount u...
# 22     10  MD-RUPEEK  shine use vehicl busi season loan rupeek gold ...
# 23     10  MM-MSGIND  ka mn applic car receiv receiv loan offer shortli
# 24     10  IX-CARTSN  thank book car servic cartisan appoint oct sho...
# 25     10  HP-CARFIN                                         verif code
# 26     10  IX-CARTSN  servic cartisan car detail underway ll updat s...
# 27     10  MM-MSGIND             loan applic approv offer rs accept app
# 28     10  MM-MSGIND                 loan agreement rs readi e sign app
# 29     10  HP-CARFIN                                         verif code
# ...    ..        ...                                                ...
# 22416  10  MD-EXCELA  dear parent student reg open crash cours summe...
# 22417  10  RM-HDFCBK  do best manag basi currenc suppli urg use hdfc...
# 22418  10  VM-SVCBNK  dear custom cashless green use svc bank debit ...
# 22419  10  RM-ICICIB  neft transact refer number rs credit beneficia...
# 22420  10  HP-CARFIN                                         verif code
# 22421  10  VK-CITIBK       rs spent credit card dec aditya birla retail
# 22422  10  RM-ICICIB  dear custom icici bank account debit dec info ...
# 22423  10  RM-CLMORE  megastor gift u cash free cash coupon free cas...
# 22424  10  RM-METROW  cashback icici credit debit card carrot cucumb...
# 22425  10  RM-CLMORE  supermarket gift u cash free cash coupon free ...
# 22426  10  VM-ICICIB                dear custom net avail balanc ac inr
# 22427  10  RM-ICICIB  dear custom ac credit dec info bil car advenc ...
# 22428  10  DM-MGCBRK  receiv new respons properti subscrib paid pack...
# 22429  10  IM-ICICIB  dear custom payment inr icici bank credit card...
# 22430  10  DM-BENTTN  popular demand extend valid bonu point rush re...
# 22431  10  AM-BESCOM  dear consum rs account id gener view pay onlin...
# 22432  10  DM-CITIBK  util credit limit credit card end limit charg ...
# 22433  10  VK-CITIBK                           rs spent credit card dec
# 22434  10  DM-MYTSKY  request complet monthli telugu rs monthli kann...
# 22435  10  DM-MYTSKY       request complet tv rs current c bal date dec
# 22436  10  DM-MYTSKY  tata sky subscrib id recharg rs instal detail ...
# 22437  10  DM-MYTSKY  tata sky instal visit wo schedul case queri pl...
# 22438  10  DM-MYTSKY  hi contact rmn work hr appoint visit tataski w...
# 22439  10  DM-MYTSKY                            otp tataski valid minut
# 22440  10  VM-VAAHAN  rto jnanabharathi ka owner satish somanna nara...
# 22441  10  DM-HSJOYY  salon home rs servic liposolubl wax christinev...
# 22442  10  DM-LNDGKT  thank regist lendingkart kindli login http app...
# 22443  10  VM-ICICIB                dear custom net avail balanc ac inr
# 22444  10  MD-WWICSG  golden chanc appli pr canada usa uk busi perso...
# 22445  10  RM-ICICIB  dear custom icici bank account debit dec info ...
#
#                     timestamp  \
# 0      2016-10-10 09:45:49+00
# 1      2016-10-10 08:33:51+00
# 2      2016-10-10 08:33:49+00
# 3      2016-10-10 07:48:41+00
# 4      2016-10-10 06:52:11+00
# 5      2016-10-10 10:22:58+00
# 6      2016-10-10 11:03:34+00
# 7      2016-10-10 11:06:57+00
# 8      2016-10-10 12:18:26+00
# 9      2016-10-10 12:19:09+00
# 10     2016-10-10 12:30:31+00
# 11     2016-10-10 12:30:34+00
# 12     2016-10-12 08:40:16+00
# 13     2016-10-11 11:42:39+00
# 14     2016-10-12 10:05:52+00
# 15     2016-10-12 10:10:10+00
# 16     2016-10-12 10:22:09+00
# 17     2016-10-12 12:25:57+00
# 18     2016-10-12 16:20:44+00
# 19     2016-10-13 07:36:17+00
# 20     2016-10-13 08:50:08+00
# 21     2016-10-13 07:59:20+00
# 22     2016-10-13 07:51:35+00
# 23     2016-10-13 09:51:02+00
# 24     2016-10-13 09:06:41+00
# 25     2016-10-13 10:00:44+00
# 26     2016-10-13 10:20:24+00
# 27     2016-10-13 10:42:48+00
# 28     2016-10-13 10:45:02+00
# 29     2016-10-13 11:01:11+00
# ...                       ...
# 22416  2016-12-02 05:10:53+00
# 22417  2016-12-02 14:04:35+00
# 22418  2016-12-02 11:41:38+00
# 22419  2016-12-03 05:58:37+00
# 22420  2016-12-03 05:45:50+00
# 22421  2016-12-03 04:07:12+00
# 22422  2016-12-03 03:05:06+00
# 22423  2016-12-03 09:23:20+00
# 22424  2016-12-03 09:21:50+00
# 22425  2016-12-03 09:26:33+00
# 22426  2016-12-03 16:03:54+00
# 22427  2016-12-03 11:53:02+00
# 22428  2016-12-03 18:16:41+00
# 22429  2016-12-04 03:56:20+00
# 22430  2016-12-04 14:56:36+00
# 22431  2016-12-04 14:27:27+00
# 22432  2016-12-04 14:17:29+00
# 22433  2016-12-04 14:15:51+00
# 22434  2016-12-04 13:12:10+00
# 22435  2016-12-04 13:10:13+00
# 22436  2016-12-04 13:05:50+00
# 22437  2016-12-04 12:11:50+00
# 22438  2016-12-04 12:05:55+00
# 22439  2016-12-04 11:37:45+00
# 22440  2016-12-05 06:44:37+00
# 22441  2016-12-05 07:43:14+00
# 22442  2016-12-05 08:00:11+00
# 22443  2016-12-05 16:10:31+00
# 22444  2016-12-05 15:44:52+00
# 22445  2016-12-05 09:53:30+00
#
#                                                       tf  \
# 0      {'code': 0.160384795471, 'verif': 0.160384795471}
# 1      {'ac': 0.0320769590943, 'avail': 0.03207695909...
# 2      {'mobil': 0.0320769590943, 'link': 0.032076959...
# 3      {'debit': 0.0213846393962, 'ac': 0.02138463939...
# 4      {'debit': 0.0213846393962, 'ac': 0.02138463939...
# 5      {'tikona': 0.0188687994672, 'servic': 0.018868...
# 6      {'singh': 0.0267307992452, 'vivek': 0.02673079...
# 7      {'close': 0.0200480994339, 'bid': 0.0200480994...
# 8      {'debit': 0.0229121136388, 'net': 0.0229121136...
# 9      {'debit': 0.0229121136388, 'min': 0.0229121136...
# 10     {'com': 0.0291608719039, 'cancel': 0.029160871...
# 11     {'com': 0.0246745839187, 'avoid': 0.0246745839...
# 12     {'code': 0.160384795471, 'verif': 0.160384795471}
# 13     {'cbc': 0.0213846393962, 'vitamind': 0.0213846...
# 14     {'applic': 0.0534615984905, 'shortli': 0.05346...
# 15     {'applic': 0.0534615984905, 'shortli': 0.05346...
# 16     {'debit': 0.0229121136388, 'amazon': 0.0229121...
# 17     {'debit': 0.0213846393962, 'ac': 0.02138463939...
# 18     {'balanc': 0.0458242272776, 'ac': 0.0458242272...
# 19     {'wd': 0.0229121136388, 'noida': 0.02291211363...
# 20     {'code': 0.160384795471, 'verif': 0.160384795471}
# 21     {'extra': 0.0160384795471, 'light': 0.01603847...
# 22     {'busi': 0.0246745839187, 'rs': 0.024674583918...
# 23     {'applic': 0.0400961988679, 'shortli': 0.04009...
# 24     {'shortli': 0.0400961988679, 'car': 0.04009619...
# 25     {'code': 0.160384795471, 'verif': 0.160384795471}
# 26     {'underway': 0.0356410656603, 'complet': 0.035...
# 27     {'accept': 0.0458242272776, 'applic': 0.045824...
# 28     {'e': 0.0458242272776, 'sign': 0.0458242272776...
# 29     {'code': 0.160384795471, 'verif': 0.160384795471}
# ...                                                  ...
# 22416  {'jee': 0.0200480994339, 'reg': 0.020048099433...
# 22417  {'basi': 0.0160384795471, 'do': 0.016038479547...
# 22418  {'debit': 0.0213846393962, 'branch': 0.0213846...
# 22419  {'number': 0.0400961988679, 'account': 0.04009...
# 22420  {'code': 0.160384795471, 'verif': 0.160384795471}
# 22421  {'card': 0.0400961988679, 'retail': 0.04009619...
# 22422  {'debit': 0.0229121136388, 'bal': 0.0229121136...
# 22423  {'u': 0.0356410656603, 'megastor': 0.035641065...
# 22424  {'tom': 0.0168826100496, 't': 0.0168826100496,...
# 22425  {'u': 0.0356410656603, 't': 0.0356410656603, '...
# 22426  {'balanc': 0.0458242272776, 'ac': 0.0458242272...
# 22427  {'ac': 0.0267307992452, 'bil': 0.0267307992452...
# 22428  {'email': 0.0229121136388, 'sm': 0.02291211363...
# 22429  {'icici': 0.0267307992452, 'credit': 0.0267307...
# 22430  {'valid': 0.0188687994672, 't': 0.018868799467...
# 22431  {'sm': 0.013946503954, 'disconnect': 0.0139465...
# 22432  {'applic': 0.0400961988679, 'util': 0.04009619...
# 22433  {'spent': 0.0641539181886, 'rs': 0.06415391818...
# 22434  {'kannada': 0.0291608719039, 'request': 0.0291...
# 22435  {'request': 0.0356410656603, 'bal': 0.03564106...
# 22436  {'recharg': 0.0356410656603, 'instal': 0.03564...
# 22437  {'schedul': 0.0291608719039, 'instal': 0.02916...
# 22438  {'attend': 0.0229121136388, 'work': 0.02291211...
# 22439  {'otp': 0.0801923977357, 'valid': 0.0801923977...
# 22440  {'somanna': 0.0106923196981, 'rc': 0.010692319...
# 22441  {'code': 0.0168826100496, 'facial': 0.01688261...
# 22442  {'year': 0.0267307992452, 'busi': 0.0133653996...
# 22443  {'balanc': 0.0458242272776, 'ac': 0.0458242272...
# 22444  {'busi': 0.0246745839187, 'farmer': 0.02467458...
# 22445  {'debit': 0.0229121136388, 'bal': 0.0229121136...
#
#                                                    tfidf
# 0      {'code': 0.160384795471, 'verif': 0.160384795471}
# 1      {'ac': 0.0320769590943, 'avail': 0.03207695909...
# 2      {'mobil': 0.0320769590943, 'link': 0.032076959...
# 3      {'debit': 0.0213846393962, 'ac': 0.02138463939...
# 4      {'debit': 0.0213846393962, 'ac': 0.02138463939...
# 5      {'tikona': 0.0188687994672, 'servic': 0.018868...
# 6      {'singh': 0.0267307992452, 'vivek': 0.02673079...
# 7      {'close': 0.0200480994339, 'bid': 0.0200480994...
# 8      {'debit': 0.0229121136388, 'net': 0.0229121136...
# 9      {'debit': 0.0229121136388, 'min': 0.0229121136...
# 10     {'com': 0.0291608719039, 'cancel': 0.029160871...
# 11     {'com': 0.0246745839187, 'avoid': 0.0246745839...
# 12     {'code': 0.160384795471, 'verif': 0.160384795471}
# 13     {'cbc': 0.0213846393962, 'vitamind': 0.0213846...
# 14     {'applic': 0.0534615984905, 'shortli': 0.05346...
# 15     {'applic': 0.0534615984905, 'shortli': 0.05346...
# 16     {'debit': 0.0229121136388, 'amazon': 0.0229121...
# 17     {'debit': 0.0213846393962, 'ac': 0.02138463939...
# 18     {'balanc': 0.0458242272776, 'ac': 0.0458242272...
# 19     {'wd': 0.0229121136388, 'noida': 0.02291211363...
# 20     {'code': 0.160384795471, 'verif': 0.160384795471}
# 21     {'extra': 0.0160384795471, 'light': 0.01603847...
# 22     {'busi': 0.0246745839187, 'rs': 0.024674583918...
# 23     {'applic': 0.0400961988679, 'shortli': 0.04009...
# 24     {'shortli': 0.0400961988679, 'car': 0.04009619...
# 25     {'code': 0.160384795471, 'verif': 0.160384795471}
# 26     {'underway': 0.0356410656603, 'complet': 0.035...
# 27     {'accept': 0.0458242272776, 'applic': 0.045824...
# 28     {'e': 0.0458242272776, 'sign': 0.0458242272776...
# 29     {'code': 0.160384795471, 'verif': 0.160384795471}
# ...                                                  ...
# 22416  {'jee': 0.0200480994339, 'reg': 0.020048099433...
# 22417  {'basi': 0.0160384795471, 'do': 0.016038479547...
# 22418  {'debit': 0.0213846393962, 'branch': 0.0213846...
# 22419  {'number': 0.0400961988679, 'account': 0.04009...
# 22420  {'code': 0.160384795471, 'verif': 0.160384795471}
# 22421  {'card': 0.0400961988679, 'retail': 0.04009619...
# 22422  {'debit': 0.0229121136388, 'bal': 0.0229121136...
# 22423  {'u': 0.0356410656603, 'megastor': 0.035641065...
# 22424  {'tom': 0.0168826100496, 't': 0.0168826100496,...
# 22425  {'u': 0.0356410656603, 't': 0.0356410656603, '...
# 22426  {'balanc': 0.0458242272776, 'ac': 0.0458242272...
# 22427  {'ac': 0.0267307992452, 'bil': 0.0267307992452...
# 22428  {'email': 0.0229121136388, 'sm': 0.02291211363...
# 22429  {'icici': 0.0267307992452, 'credit': 0.0267307...
# 22430  {'valid': 0.0188687994672, 't': 0.018868799467...
# 22431  {'sm': 0.013946503954, 'disconnect': 0.0139465...
# 22432  {'applic': 0.0400961988679, 'util': 0.04009619...
# 22433  {'spent': 0.0641539181886, 'rs': 0.06415391818...
# 22434  {'kannada': 0.0291608719039, 'request': 0.0291...
# 22435  {'request': 0.0356410656603, 'bal': 0.03564106...
# 22436  {'recharg': 0.0356410656603, 'instal': 0.03564...
# 22437  {'schedul': 0.0291608719039, 'instal': 0.02916...
# 22438  {'attend': 0.0229121136388, 'work': 0.02291211...
# 22439  {'otp': 0.0801923977357, 'valid': 0.0801923977...
# 22440  {'somanna': 0.0106923196981, 'rc': 0.010692319...
# 22441  {'code': 0.0168826100496, 'facial': 0.01688261...
# 22442  {'year': 0.0267307992452, 'busi': 0.0133653996...
# 22443  {'balanc': 0.0458242272776, 'ac': 0.0458242272...
# 22444  {'busi': 0.0246745839187, 'farmer': 0.02467458...
# 22445  {'debit': 0.0229121136388, 'bal': 0.0229121136...
#
# [22446 rows x 6 columns]
